# %% [markdown]
# # **TCR Innovation Python Project-3**
# # Tic Tac Toe Game

# %%
theBoard = {'7': ' ', '8': ' ', '9': ' ',
            '4': ' ', '5': ' ', '6': ' ',
            '1': ' ', '2': ' ', '3': ' '}

board_keys = []
temp = False

for key in theBoard:
    board_keys.append(key)

def printBoard(board):
    print()
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('-+-+-')
    print(board['1'] + '|' + board['2'] + '|' + board['3'])

def helpboard():
    print()
    print('7|8|9')
    print('-+-+-')
    print('4|5|6')
    print('-+-+-')
    print('1|2|3')

def game():
    turn = 'X'
    count = 0

    for i in range(10):
        printBoard(theBoard)
        print('\n' + turn + ' turn')
        move = input("Enter place to move = ")

        if theBoard[move] == ' ':
           theBoard[move] = turn
           count += 1
        else:
            print("That place is already filled. Move to another place!")
            continue

        if count >= 5:
            if theBoard['7'] ==  theBoard['8'] == theBoard['9'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(" **** " + turn + " won. ****")
                break
            elif theBoard['4'] == theBoard['5'] == theBoard['6'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break
            elif theBoard['1'] == theBoard['2'] == theBoard['3'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break
            elif theBoard['1'] == theBoard['4'] == theBoard['7'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break
            elif theBoard['2'] == theBoard['5'] == theBoard['8'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break
            elif theBoard['3'] == theBoard['6'] == theBoard['9'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break
            elif theBoard['7'] == theBoard['5'] == theBoard['3'] != ' ':
                printBoard(theBoard)
                print("\nGame Over. \n")
                print(turn + " won the game.")
                break

        if count == 9:
            print("\nGame Over. \n")
            print("It's a Tie!!")


        if turn == 'X':
            turn = 'O'
        else:
            turn = 'X'

while temp != True:
    print("\nTic Tac Toe Game")
    helpboard()
    print("\nAlways fill your X and O with above numbers to make your move in that position!")
    game()
    response = input("Thanks for playing.  Play again? (y/n) :")
    if response == 'y':
        temp = False
        for key in board_keys:
            theBoard[key] = " "
    elif response == 'n':
        temp = True
        print("Bye..")
# Out:
# Tic Tac Toe Game
#
# 7|8|9
# -+-+-
# 4|5|6
# -+-+-
# 1|2|3
#
# Always fill your X and O with above numbers to make your move in that position!
#
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
#
# X turn
# Enter place to move = 7
#
# X| |
# -+-+-
#  | |
# -+-+-
#  | |
#
# O turn
# Enter place to move = 2
#
# X| |
# -+-+-
#  | |
# -+-+-
#  |O|
#
# X turn
# Enter place to move = 3
#
# X| |
# -+-+-
#  | |
# -+-+-
#  |O|X
#
# O turn
# Enter place to move = 5
#
# X| |
# -+-+-
#  |O|
# -+-+-
#  |O|X
#
# X turn
# Enter place to move = 1
#
# X| |
# -+-+-
#  |O|
# -+-+-
# X|O|X
#
# O turn
# Enter place to move = 8
#
# X|O|
# -+-+-
#  |O|
# -+-+-
# X|O|X
#
# Game Over.
#
# O won the game.
# Thanks for playing.  Play again? (y/n) :y
#
# Tic Tac Toe Game
#
# 7|8|9
# -+-+-
# 4|5|6
# -+-+-
# 1|2|3
#
# Always fill your X and O with above numbers to make your move in that position!
#
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
#
# X turn
# Enter place to move = 1
#
#  | |
# -+-+-
#  | |
# -+-+-
# X| |
#
# O turn
# ...
