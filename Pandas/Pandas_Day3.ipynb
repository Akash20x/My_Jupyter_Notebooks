# %%
import pandas as pd
import numpy as np

# %%
# pd?

# %%
# pd.Series?

# %%
s1=pd.Series(["blue","red","green"],name="colors")
s2=pd.Series(["b","r","g"],name="first_letter")

# %%
df=pd.DataFrame([s1,s2])

# %%
df
# Out:
#                  0    1      2
# colors        blue  red  green
# first_letter     b    r      g

# %%
df.T
# Out:
#   colors first_letter
# 0   blue            b
# 1    red            r
# 2  green            g

# %%
df=pd.read_csv("/content/HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  Departments   salary
# 0                    0.38             0.53  ...         sales     low
# 1                    0.80             0.86  ...         sales  medium
# 2                    0.11             0.88  ...         sales  medium
# 3                    0.72             0.87  ...         sales     low
# 4                    0.37             0.52  ...         sales     low
# ...                   ...              ...  ...           ...     ...
# 14994                0.40             0.57  ...       support     low
# 14995                0.37             0.48  ...       support     low
# 14996                0.37             0.53  ...       support     low
# 14997                0.11             0.96  ...       support     low
# 14998                0.37             0.52  ...       support     low
#
# [14999 rows x 10 columns]

# %%
df.describe(include='all')
# Out:
#         satisfaction_level  last_evaluation  ...  Departments   salary
# count         14999.000000     14999.000000  ...         14999   14999
# unique                 NaN              NaN  ...            10       3
# top                    NaN              NaN  ...         sales     low
# freq                   NaN              NaN  ...          4140    7316
# mean              0.612834         0.716102  ...           NaN     NaN
# std               0.248631         0.171169  ...           NaN     NaN
# min               0.090000         0.360000  ...           NaN     NaN
# 25%               0.440000         0.560000  ...           NaN     NaN
# 50%               0.640000         0.720000  ...           NaN     NaN
# 75%               0.820000         0.870000  ...           NaN     NaN
# max               1.000000         1.000000  ...           NaN     NaN
#
# [11 rows x 10 columns]

# %%
df['number_project'].hist()

# %%
df=df.sort_values(by='number_project')
df
# Out:
#        satisfaction_level  last_evaluation  ...  Departments   salary
# 0                    0.38             0.53  ...         sales     low
# 7590                 0.68             0.64  ...            hr     low
# 7604                 0.73             0.52  ...       support  medium
# 7608                 0.30             0.85  ...       support  medium
# 7610                 0.49             0.83  ...       support  medium
# ...                   ...              ...  ...           ...     ...
# 12497                0.59             0.49  ...     technical  medium
# 172                  0.11             0.78  ...         sales     low
# 1214                 0.09             0.87  ...            IT     low
# 165                  0.11             0.84  ...         sales     low
# 1676                 0.10             0.81  ...         RandD  medium
#
# [14999 rows x 10 columns]

# %%
df=df.sort_index()
df
# Out:
#        satisfaction_level  last_evaluation  ...  Departments   salary
# 0                    0.38             0.53  ...         sales     low
# 1                    0.80             0.86  ...         sales  medium
# 2                    0.11             0.88  ...         sales  medium
# 3                    0.72             0.87  ...         sales     low
# 4                    0.37             0.52  ...         sales     low
# ...                   ...              ...  ...           ...     ...
# 14994                0.40             0.57  ...       support     low
# 14995                0.37             0.48  ...       support     low
# 14996                0.37             0.53  ...       support     low
# 14997                0.11             0.96  ...       support     low
# 14998                0.37             0.52  ...       support     low
#
# [14999 rows x 10 columns]

# %%
df['new']=df['time_spend_company']*3

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  salary  new
# 0                    0.38             0.53  ...     low    9
# 1                    0.80             0.86  ...  medium   18
# 2                    0.11             0.88  ...  medium   12
# 3                    0.72             0.87  ...     low   15
# 4                    0.37             0.52  ...     low    9
# ...                   ...              ...  ...     ...  ...
# 14994                0.40             0.57  ...     low    9
# 14995                0.37             0.48  ...     low    9
# 14996                0.37             0.53  ...     low    9
# 14997                0.11             0.96  ...     low   12
# 14998                0.37             0.52  ...     low    9
#
# [14999 rows x 11 columns]

# %%
def satisfaction_label(x):
  if x >=.70:
    return "High"
  elif x <0.40:
    return "low"
  else:
    return "medium"

# %%
df['satisfaction_level'].map(satisfaction_label)
# Out:
# 0           low
# 1          High
# 2           low
# 3          High
# 4           low
#           ...
# 14994    medium
# 14995       low
# 14996       low
# 14997       low
# 14998       low
# Name: satisfaction_level, Length: 14999, dtype: object

# %%
df['satisfaction_level'].map(satisfaction_label).value_counts()
# Out:
# High      6503
# medium    5581
# low       2915
# Name: satisfaction_level, dtype: int64

# %%
df['satisfaction_new']=df['satisfaction_level'].map(satisfaction_label)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    0.38             0.53  ...    9               low
# 1                    0.80             0.86  ...   18              High
# 2                    0.11             0.88  ...   12               low
# 3                    0.72             0.87  ...   15              High
# 4                    0.37             0.52  ...    9               low
# ...                   ...              ...  ...  ...               ...
# 14994                0.40             0.57  ...    9            medium
# 14995                0.37             0.48  ...    9               low
# 14996                0.37             0.53  ...    9               low
# 14997                0.11             0.96  ...   12               low
# 14998                0.37             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df[df['time_spend_company'].map(lambda x:x==2)].reset_index(drop='True')
# Out:
#       satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                   0.13             0.78  ...    6               low
# 1                   0.86             0.68  ...    6              High
# 2                   0.54             0.74  ...    6            medium
# 3                   0.56             0.71  ...    6            medium
# 4                   0.31             0.56  ...    6               low
# ...                  ...              ...  ...  ...               ...
# 3239                0.32             0.95  ...    6               low
# 3240                0.48             0.78  ...    6            medium
# 3241                0.80             0.75  ...    6              High
# 3242                0.34             0.67  ...    6               low
# 3243                0.73             0.97  ...    6              High
#
# [3244 rows x 12 columns]

# %%
df['last_evaluation'].round().value_counts()
# Out:
# 1.0    13078
# 0.0     1921
# Name: last_evaluation, dtype: int64

# %%
df['promotion_last_5years'].value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
gb=df.groupby("promotion_last_5years")
gb.mean()['average_montly_hours']
# Out:
# promotion_last_5years
# 0    201.076431
# 1    199.849530
# Name: average_montly_hours, dtype: float64

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    0.38             0.53  ...    9               low
# 1                    0.80             0.86  ...   18              High
# 2                    0.11             0.88  ...   12               low
# 3                    0.72             0.87  ...   15              High
# 4                    0.37             0.52  ...    9               low
# ...                   ...              ...  ...  ...               ...
# 14994                0.40             0.57  ...    9            medium
# 14995                0.37             0.48  ...    9               low
# 14996                0.37             0.53  ...    9               low
# 14997                0.11             0.96  ...   12               low
# 14998                0.37             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df.to_csv("new.csv",index=False)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    0.38             0.53  ...    9               low
# 1                    0.80             0.86  ...   18              High
# 2                    0.11             0.88  ...   12               low
# 3                    0.72             0.87  ...   15              High
# 4                    0.37             0.52  ...    9               low
# ...                   ...              ...  ...  ...               ...
# 14994                0.40             0.57  ...    9            medium
# 14995                0.37             0.48  ...    9               low
# 14996                0.37             0.53  ...    9               low
# 14997                0.11             0.96  ...   12               low
# 14998                0.37             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df['Work_accident'].value_counts()
# Out:
# 0    12830
# 1     2169
# Name: Work_accident, dtype: int64

# %%
df['salary']=df['salary'].apply(lambda x: 0 if x=='low' else (1 if x=='medium' else 2))

# %%
df
# Out:
#        satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    0.38             0.53  ...    9               low
# 1                    0.80             0.86  ...   18              High
# 2                    0.11             0.88  ...   12               low
# 3                    0.72             0.87  ...   15              High
# 4                    0.37             0.52  ...    9               low
# ...                   ...              ...  ...  ...               ...
# 14994                0.40             0.57  ...    9            medium
# 14995                0.37             0.48  ...    9               low
# 14996                0.37             0.53  ...    9               low
# 14997                0.11             0.96  ...   12               low
# 14998                0.37             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df['satisfaction_level']=df['satisfaction_level'].apply(lambda x: "Low" if float(x)==float(0.38) else None)

# %%
df
# Out:
#       satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    Low             0.53  ...    9               low
# 1                   None             0.86  ...   18              High
# 2                   None             0.88  ...   12               low
# 3                   None             0.87  ...   15              High
# 4                   None             0.52  ...    9               low
# ...                  ...              ...  ...  ...               ...
# 14994               None             0.57  ...    9            medium
# 14995               None             0.48  ...    9               low
# 14996               None             0.53  ...    9               low
# 14997               None             0.96  ...   12               low
# 14998               None             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df['satisfaction_level']
# Out:
# 0         Low
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 14994    None
# 14995    None
# 14996    None
# 14997    None
# 14998    None
# Name: satisfaction_level, Length: 14999, dtype: object

# %%
df=df.fillna('High')

# %%
df['satisfaction_level'].value_counts()
# Out:
# High    14810
# Low       189
# Name: satisfaction_level, dtype: int64

# %%
df
# Out:
#       satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    Low             0.53  ...    9               low
# 1                   High             0.86  ...   18              High
# 2                   High             0.88  ...   12               low
# 3                   High             0.87  ...   15              High
# 4                   High             0.52  ...    9               low
# ...                  ...              ...  ...  ...               ...
# 14994               High             0.57  ...    9            medium
# 14995               High             0.48  ...    9               low
# 14996               High             0.53  ...    9               low
# 14997               High             0.96  ...   12               low
# 14998               High             0.52  ...    9               low
#
# [14999 rows x 12 columns]

# %%
df[df['time_spend_company'].isin(['3','4'])]
# Out:
#       satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 0                    Low             0.53  ...    9               low
# 2                   High             0.88  ...   12               low
# 4                   High             0.52  ...    9               low
# 5                   High             0.50  ...    9            medium
# 6                   High             0.77  ...   12               low
# ...                  ...              ...  ...  ...               ...
# 14994               High             0.57  ...    9            medium
# 14995               High             0.48  ...    9               low
# 14996               High             0.53  ...    9               low
# 14997               High             0.96  ...   12               low
# 14998               High             0.52  ...    9               low
#
# [9000 rows x 12 columns]

# %%
df[~df['time_spend_company'].isin(['3','4'])]
# Out:
#       satisfaction_level  last_evaluation  ...  new  satisfaction_new
# 1                   High             0.86  ...   18              High
# 3                   High             0.87  ...   15              High
# 7                   High             0.85  ...   15              High
# 8                   High             1.00  ...   15              High
# 12                  High             0.92  ...   15              High
# ...                  ...              ...  ...  ...               ...
# 14983               High             0.84  ...   15              High
# 14985               High             0.99  ...   15              High
# 14986               High             0.85  ...   18              High
# 14990               High             0.88  ...   15              High
# 14993               High             0.83  ...   18              High
#
# [5999 rows x 12 columns]

# %%
df=df.rename(columns={"satisfaction_new":"Satisfaction_Category","time_spend_company":"Time Period"})

# %%
df
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 0                    Low             0.53  ...    9                    low
# 1                   High             0.86  ...   18                   High
# 2                   High             0.88  ...   12                    low
# 3                   High             0.87  ...   15                   High
# 4                   High             0.52  ...    9                    low
# ...                  ...              ...  ...  ...                    ...
# 14994               High             0.57  ...    9                 medium
# 14995               High             0.48  ...    9                    low
# 14996               High             0.53  ...    9                    low
# 14997               High             0.96  ...   12                    low
# 14998               High             0.52  ...    9                    low
#
# [14999 rows x 12 columns]

# %%
df.sort_values(by='average_montly_hours',ascending=False).reset_index(drop=True)
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 0                   High             0.77  ...   12                    low
# 1                   High             0.97  ...   12                    low
# 2                   High             0.96  ...   12                    low
# 3                   High             0.79  ...   12                    low
# 4                   High             0.97  ...   12                    low
# ...                  ...              ...  ...  ...                    ...
# 14994               High             0.82  ...   12                   High
# 14995               High             0.61  ...   12                   High
# 14996               High             0.98  ...    6                    low
# 14997               High             0.43  ...    9                 medium
# 14998               High             0.67  ...    6                    low
#
# [14999 rows x 12 columns]

# %%
df
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 0                    Low             0.53  ...    9                    low
# 1                   High             0.86  ...   18                   High
# 2                   High             0.88  ...   12                    low
# 3                   High             0.87  ...   15                   High
# 4                   High             0.52  ...    9                    low
# ...                  ...              ...  ...  ...                    ...
# 14994               High             0.57  ...    9                 medium
# 14995               High             0.48  ...    9                    low
# 14996               High             0.53  ...    9                    low
# 14997               High             0.96  ...   12                    low
# 14998               High             0.52  ...    9                    low
#
# [14999 rows x 12 columns]

# %%
df['satisfaction_level']=df['satisfaction_level'].str.lower()

# %%
df
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 0                    low             0.53  ...    9                    low
# 1                   high             0.86  ...   18                   High
# 2                   high             0.88  ...   12                    low
# 3                   high             0.87  ...   15                   High
# 4                   high             0.52  ...    9                    low
# ...                  ...              ...  ...  ...                    ...
# 14994               high             0.57  ...    9                 medium
# 14995               high             0.48  ...    9                    low
# 14996               high             0.53  ...    9                    low
# 14997               high             0.96  ...   12                    low
# 14998               high             0.52  ...    9                    low
#
# [14999 rows x 12 columns]

# %%
df[~df['Departments '].str.contains("s.")]
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 28                  high             0.46  ...    9                 medium
# 29                   low             0.50  ...    9                    low
# 30                  high             0.62  ...   12                    low
# 31                  high             0.57  ...    9                 medium
# 32                  high             0.51  ...    9                 medium
# ...                  ...              ...  ...  ...                    ...
# 14985               high             0.99  ...   15                   High
# 14986               high             0.85  ...   18                   High
# 14987               high             0.70  ...   12                   High
# 14988               high             0.55  ...    9                 medium
# 14989               high             0.57  ...    9                 medium
#
# [8630 rows x 12 columns]

# %%
df.reset_index(drop=True)
# Out:
#       satisfaction_level  last_evaluation  ...  new  Satisfaction_Category
# 0                    low             0.53  ...    9                    low
# 1                   high             0.86  ...   18                   High
# 2                   high             0.88  ...   12                    low
# 3                   high             0.87  ...   15                   High
# 4                   high             0.52  ...    9                    low
# ...                  ...              ...  ...  ...                    ...
# 14994               high             0.57  ...    9                 medium
# 14995               high             0.48  ...    9                    low
# 14996               high             0.53  ...    9                    low
# 14997               high             0.96  ...   12                    low
# 14998               high             0.52  ...    9                    low
#
# [14999 rows x 12 columns]

# %%
# df_to_add={'satisfaction_level':['medium'],"last_evaluation":[0.99],"number_project":[42],"average_montly_hours":[100,200],
#            "Time Period":[8,5,4],"Work_accident":[0],"left":3,"promotion_last_5years":[1],"Departments ":["Tech","game"],"salary":[1],
#            "new":5,"Satisfaction_Category":["Unknown"]}
# df_to_add=pd.DataFrame(columns=df.columns,data=df_to_add)
# df_to_add

# %%
df.groupby('Departments ')['average_montly_hours'].mean()
# Out:
# Departments
# IT             202.215974
# RandD          200.800508
# accounting     201.162973
# hr             198.684709
# management     201.249206
# marketing      199.385781
# product_mng    199.965632
# sales          200.911353
# support        200.758188
# technical      202.497426
# Name: average_montly_hours, dtype: float64

# %%
df.plot()

# %%
df[['number_project','salary']].plot(x='number_project',y='salary',kind='scatter',figsize=(8,5))

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2eb87f3d0>,
# ...
#       dtype=object)

# %%
df.hist(figsize=(20,10),bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2eb591dd0>,
# ...
#       dtype=object)
